# %% [markdown]
# ## Configuration

# %%
### Configuration
# Import dependencies
import os
from collections import Counter
from datetime import datetime
from dateutil.relativedelta import relativedelta
import pandas as pd
from summerplaylist import *

# Environment variables
CLIENTID = os.environ.get('CLIENTID')
CLIENTSECRET = os.environ.get('CLIENTSECRET')
REDIRECT_URI = 'https://example.com/callback'

# %% [markdown]
# ## Log In

# %%
# Authenticate to Spotify
credentials = authenticateToSpotify(CLIENTID, CLIENTSECRET, REDIRECT_URI)
# Out:
# Opening browser for Spotify login...

# %% [markdown]
# ## Get playlist info

# %%
playlistID = getPlaylistID(credentials, "Forever Summer 2024")

# %%
# def fetchPlaylistInfoAll(credentials, playlistID):
#     spotify, userID, user_token = credentials
#     offset = 0
#     limit = 100
#     nestedList = ["empty"]
#     result = pd.DataFrame()
#     # Loop through the offsets until there are no more trac ks
#     while len(nestedList) > 0:
#         # Get all artists in the list from spotify
#         nestedList = [[{
#             "artistName":y.name, 
#             "artistID":y.id, 
#             "songName":x.track.name, 
#             "albumReleaseDate":x.track.album.release_date, 
#             "songURI":x.track.uri,
#             "songLocation":x.track.track_number,
#             "albumLength":x.track.album.total_tracks,
#             "songDuration":x.track.duration_ms,
#             "songExplicit":x.track.explicit,
#             "songPopularity":x.track.popularity,
#             } for y in x.track.artists
#             ] for x in spotify.playlist_items(playlistID, offset=offset, limit=limit).items]
#         # Unnest the list 
#         unnestedList = [item for sublist in nestedList for item in sublist]
#         toAdd = pd.DataFrame(unnestedList)
#         # Concatenate new additions
#         result = pd.concat([result, toAdd], axis=0, ignore_index=True)
#         # Increment counter
#         offset += 100
#     return result

# %%
allTracks = fetchTracksFromPlaylist(credentials, playlistID)
allTracks = allTracks.drop_duplicates('songURI', ignore_index=True)

# %%
sfw = allTracks.loc[allTracks.songExplicit==False]
sfw
# Out:
#       artistName                artistID  \
# 0     Noah Kahan  2RQXRUsr4IW1f3mKyKsy4B
# 3      easy life  7uwY65fDg3FVJ8MkJ5QuZK
# 5        Georgia  06knYh538h5SI7OAEF8ek3
# 7    underscores  7HfUJxeVTgrvhk0eWHFzV7
# 9          Marta  0yz9lVc98Tji7yjwkUe7l7
# ..           ...                     ...
# 439  Say She She  1WGb8nCPGJA0RyriSDIQfC
# 440  Mindchatter  1He0ZKninbT4FMEV9hUZKn
# 441      Oceanic  1HZqEalU7MGNHQvENPJb4J
# 442      Oceanic  1HZqEalU7MGNHQvENPJb4J
# 443   Eartheater  18ca9d5EU5R1AhVKPR1cm0
#
#                                       songName release_date  \
# 0       Paul Revere (with Gregory Alan Isakov)   2024-02-09
# 3                                          OTT   2022-10-07
# 5                                It’s Euphoric   2023-07-28
# 7    Locals (Girls like us) [with gabby start]   2023-09-22
# 9                                 Think Of You   2023-03-31
# ..                                         ...          ...
# 439                                    Reeling   2023-09-29
# 440                              It's Been You   2020-10-21
# 441                              When You Fall   2023-01-27
# 442                           Change Your Mind   2021-01-15
# 443                                   Crushing   2023-09-20
#
#                                   songURI  songLocation  albumLength  \
# 0    spotify:track:6BTAzOm96NwuGXhfHqWYM4            30           30
# 3    spotify:track:7vfVFDOOwErIDLt2vi2Q3W             6           15
# 5    spotify:track:7ynqVX9l6jWPDduSJwIiYG             1           10
# 7    spotify:track:0MK6lVnmhVulpP62vkZBWV             2           12
# 9    spotify:track:6DoorW57JlryA2QdYIoxfS             5            9
# ..                                    ...           ...          ...
# 439  spotify:track:5gl1jdCfkqgWIzltobaVNO             1           16
# 440  spotify:track:7e1dQ6se0Ordm8sNCdEkkn             7           13
# 441  spotify:track:32p9aZukoL6KZqAEOqRfNc             5           11
# 442  spotify:track:0ryVvXd2EzVqNR0yTLCzNT             1            1
# 443  spotify:track:6BPwBHxjmavFAyMrLQgQYd             2            9
#
#      songDuration  songExplicit  songPopularity
# 0          213313         False              65
# 3          157817         False              44
# 5          221493         False              30
# 7          258084         False              50
# 9          137386         False              35
# ..            ...           ...             ...
# 439        220520         False              37
# 440        193956         False              51
# 441        170213         False              30
# 442        188866         False              32
# 443        271733         False              51
#
# [314 rows x 10 columns]

# %%
plSFW = getPlaylistID(credentials, 'SFW Summer 2024')
addToPlaylist(credentials, sfw['songURI'].to_list(), plSFW)
