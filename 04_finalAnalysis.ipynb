# %% [markdown]
# ## Configuration

# %%
### Configuration
# Import dependencies
import os
from collections import Counter
from datetime import datetime
from dateutil.relativedelta import relativedelta
import pandas as pd
from summerplaylist import *

# Environment variables
CLIENTID = os.environ.get('CLIENTID')
CLIENTSECRET = os.environ.get('CLIENTSECRET')
REDIRECT_URI = 'https://example.com/callback'

# %% [markdown]
# ## Log In

# %%
# Authenticate to Spotify
credentials = authenticateToSpotify(CLIENTID, CLIENTSECRET, REDIRECT_URI)
# Out:
# Opening browser for Spotify login...

# %% [markdown]
# ## Get playlist info

# %%
playlistID = getPlaylistID(credentials, "Forever Summer 2023")

# %%
# def fetchPlaylistInfoAll(credentials, playlistID):
#     spotify, userID, user_token = credentials
#     offset = 0
#     limit = 100
#     nestedList = ["empty"]
#     result = pd.DataFrame()
#     # Loop through the offsets until there are no more trac ks
#     while len(nestedList) > 0:
#         # Get all artists in the list from spotify
#         nestedList = [[{
#             "artistName":y.name, 
#             "artistID":y.id, 
#             "songName":x.track.name, 
#             "albumReleaseDate":x.track.album.release_date, 
#             "songURI":x.track.uri,
#             "songLocation":x.track.track_number,
#             "albumLength":x.track.album.total_tracks,
#             "songDuration":x.track.duration_ms,
#             "songExplicit":x.track.explicit,
#             "songPopularity":x.track.popularity,
#             } for y in x.track.artists
#             ] for x in spotify.playlist_items(playlistID, offset=offset, limit=limit).items]
#         # Unnest the list 
#         unnestedList = [item for sublist in nestedList for item in sublist]
#         toAdd = pd.DataFrame(unnestedList)
#         # Concatenate new additions
#         result = pd.concat([result, toAdd], axis=0, ignore_index=True)
#         # Increment counter
#         offset += 100
#     return result

# %%
allTracks = fetchTracksFromPlaylist(credentials, playlistID)
allTracks = allTracks.drop_duplicates('songURI', ignore_index=True)
# Out:
#              artistName                artistID  \
# 0               Cam’ron  7iMvwE8qANp3aIfAGKEAwS
# 1            Noah Kahan  2RQXRUsr4IW1f3mKyKsy4B
# 2              Måneskin  0lAWpj5szCSwM4rUMHYmrr
# 3              100 gecs  6PfSUFtkMVoDkx4MQkzOi3
# 4          Nana Lourdes  3LEjiFgpLbT1F0UgOE9qbg
# ..                  ...                     ...
# 424              Tiësto  2o5jDhtHVPhrJdv3cEQ99Z
# 425        The Midnight  2NFrAuh8RQdQoS7iYFbckw
# 426  Falling In Reverse  2CmaKO2zEGJ1NWpS1yfVGz
# 427        Milky Chance  1hzfo8twXdOegF3xireCYs
# 428        Zara Larsson  1Xylc3o4UrD53lo9CvFvVg
#
#                            songName albumReleaseDate  \
# 0                          Dipshits       2022-09-23
# 1                      Stick Season       2022-10-14
# 2        GOSSIP (feat. Tom Morello)       2023-01-20
# 3                    Hollywood Baby       2023-03-17
# 4                    Fuck Up Person       2022-11-11
# ..                              ...              ...
# 424                         Lay Low       2023-01-06
# 425                     Golden Gate       2022-10-28
# 426            Watch The World Burn       2023-01-31
# 427  Do You Really Want To Hurt Me?       2022-10-05
# 428                    Ruin My Life       2021-03-05
#
#                                   songURI  songLocation  albumLength  \
# 0    spotify:track:1MFPZAOgNGPY6eV6OiRq0q             9            9
# 1    spotify:track:0mflMxspEfB0VbI1kyLiAv             2           14
# 2    spotify:track:44Xyja7xYPlVC6v2CeweSi             2           17
# 3    spotify:track:0oigSejhoNen2EdNAIFcm5             3           10
# 4    spotify:track:6VragNqSp2liUsisozixzH             9           10
# ..                                    ...           ...          ...
# 424  spotify:track:0zKbDrEXKpnExhGQRe9dxt             1            1
# 425  spotify:track:3mSvhf4KToJtU9U9qqxUWS             1           25
# 426  spotify:track:4CiVz4bw7X1zjCaJ5ZwxUS             1            1
# 427  spotify:track:7hA7ImyAWuT0YPY5k6B0my             4           12
# 428  spotify:track:4nyY8oVjbX2d4qzlpiVM5n             9           12
#
#      songDuration  songExplicit  songPopularity
# 0          211560          True              30
# 1          182346         False              79
# 2          168280          True              79
# 3          187693          True              68
# 4          255817          True              15
# ..            ...           ...             ...
# 424        153442         False              86
# 425        364871         False              32
# 426        203948          True              79
# 427        271480         False              47
# 428        190050          True              65
#
# [429 rows x 10 columns]

# %%
sfw = allTracks.loc[allTracks.songExplicit==False]
sfw
# Out:
#           artistName                artistID                        songName  \
# 1         Noah Kahan  2RQXRUsr4IW1f3mKyKsy4B                    Stick Season
# 5            Käärijä  6LkMGN0t3HDNL8hIvma70r                     Cha Cha Cha
# 6         Atmosphere  1GAS0rb4L8VTPvizAx2O9J                        Sterling
# 7       Danger Mouse  2dBj3prW7gP9bCCOIQeDUf                     Cheat Codes
# 8    Homeboy Sandman  5s1QeAf7U5ELP9PTeLaicb                         Go Hard
# ..               ...                     ...                             ...
# 422           Alesso  4AVFqumd2ogHFlRbKIjp1t      Words (feat. Zara Larsson)
# 423   Regina Spektor  3z6Gk257P9jNcZbBXJNX5i                 Up the Mountain
# 424           Tiësto  2o5jDhtHVPhrJdv3cEQ99Z                         Lay Low
# 425     The Midnight  2NFrAuh8RQdQoS7iYFbckw                     Golden Gate
# 427     Milky Chance  1hzfo8twXdOegF3xireCYs  Do You Really Want To Hurt Me?
#
#     albumReleaseDate                               songURI  songLocation  \
# 1         2022-10-14  spotify:track:0mflMxspEfB0VbI1kyLiAv             2
# 5         2023-01-17  spotify:track:5RX8T3EoTuXcybAxe6oPAw             1
# 6         2023-05-05  spotify:track:16wjUVIiWL2eVCIGHe2Qgd             3
# 7         2022-08-12  spotify:track:4eAT5VkDtmQGcNAUNdeo3R             2
# 8         2022-07-29  spotify:track:0NR1mC84y8AZLOGrS5c63X             1
# ..               ...                                   ...           ...
# 422       2022-04-22  spotify:track:1bgKMxPQU7JIZEhNsM1vFs             1
# 423       2022-06-24  spotify:track:2g4AwvRQWr80aORzUhoNEq             2
# 424       2023-01-06  spotify:track:0zKbDrEXKpnExhGQRe9dxt             1
# 425       2022-10-28  spotify:track:3mSvhf4KToJtU9U9qqxUWS             1
# 427       2022-10-05  spotify:track:7hA7ImyAWuT0YPY5k6B0my             4
#
#      albumLength  songDuration  songExplicit  songPopularity
# 1             14        182346         False              79
# 5              1        175161         False              89
# 6             20         72053         False              43
# 7             12        134626         False              14
# 8             16        204524         False              23
# ..           ...           ...           ...             ...
# 422            1        142677         False              83
# 423           10        280840         False              37
# 424            1        153442         False              86
# 425           25        364871         False              32
# 427           12        271480         False              47
#
# [318 rows x 10 columns]

# %%
plSFW = getPlaylistID(credentials, 'SFW Summer 2023')
addToPlaylist(credentials, sfw['songURI'].to_list(), plSFW)
