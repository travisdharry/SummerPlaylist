# %% [markdown]
# ## Config

# %%
# Import dependencies
import tekore as tk
import os
import time
import pandas as pd
import numpy as np
from datetime import datetime, date
from dateutil.relativedelta import relativedelta

# Environment variables
CLIENTID = os.environ.get('CLIENTID')
CLIENTSECRET = os.environ.get('CLIENTSECRET')
REDIRECT_URI = 'https://example.com/callback'

# %%
### Authenticate Tekore and Authorize App
# Get client token
app_token = tk.request_client_token(CLIENTID, CLIENTSECRET)
# Get a user token; Note the need to ask for write scope in order to create/edit playlists
# This will open a browser window; the user will need to copy the URL from the browser and paste it into the VSCode Command Palette
user_token = tk.prompt_for_user_token(CLIENTID, CLIENTSECRET, REDIRECT_URI, scope=tk.scope.write)
# Create spotify instance
spotify = tk.Spotify(app_token)
# Get the user's spotifyID; The spotify instance will have to reference the user_token to be authorized for this data
with spotify.token_as(user_token):
    userID = spotify.current_user().id
# Out:
# Opening browser for Spotify login...

# %% [markdown]
# ## Get some songs and sort them

# %%
# Extract list of songs
songs = pd.read_csv('songs2.csv')

# Clean
# Convert to datetime
songs['albumReleaseDate'] = pd.to_datetime(songs['albumReleaseDate'])

# Sort
# Create a categorical sort order
priorPlaylists = [
    '2023',
    'Summer 2022',
    'Summer 2021',
    'Summer 2020',
    'Summer 2019',
    'Summer 2018',
    'anti pop',
    'big on the internet',
    'Lorem',
    'Alternative Hip-Hop',
    'Et-Alt'
]
songs['artistSource'] = pd.Categorical(songs['artistSource'], categories=priorPlaylists)
songs = songs.sort_values(by=['artistSource', 'artistGenreUnique', 'artistID', 'albumID'], ignore_index=True)

# %%
# Filter
# Date
MINDATE = datetime((date.today() - relativedelta(years=1)).year, 6, 1)
filDate = songs.albumReleaseDate>=MINDATE
# Album Type
filAType = songs.albumType=='album'
# Filter
songs = songs.loc[filDate & filAType].reset_index(drop=True)

# %%
songsA = songs

# %%
# Filter
# Date
MINDATE = datetime((date.today() - relativedelta(years=1)).year, 3, 17)
MAXDATE = datetime((date.today() - relativedelta(years=1)).year, 5, 31)
filDateMin = songs.albumReleaseDate>=MINDATE
filDateMax = songs.albumReleaseDate<=MAXDATE
# Album Type
filAType = songs.albumType=='album'
# Playlist type
myPlaylists = [
    '2023',
    'Summer 2022',
    'Summer 2021',
    'Summer 2020',
    'Summer 2019',
    'Summer 2018',
]
filPlay = songs.artistSource.isin(myPlaylists)
# Filter
songs = songs.loc[filDateMin & filDateMax & filAType & filPlay].reset_index(drop=True)

# %%
songs
# Out:
#                    artistID artistName artistSource  artistPopularity  \
# 0    5jQsMNuCW0iZeFTz6YUK8K  Pluralone         2023                28
# 1    5jQsMNuCW0iZeFTz6YUK8K  Pluralone         2023                28
# 2    5jQsMNuCW0iZeFTz6YUK8K  Pluralone         2023                28
# 3    5jQsMNuCW0iZeFTz6YUK8K  Pluralone         2023                28
# 4    5jQsMNuCW0iZeFTz6YUK8K  Pluralone         2023                28
# ..                      ...        ...          ...               ...
# 745  0ZxZlO7oWCSYMXhehpyMvE       COIN  Summer 2018                64
# 746  0ZxZlO7oWCSYMXhehpyMvE       COIN  Summer 2018                64
# 747  0ZxZlO7oWCSYMXhehpyMvE       COIN  Summer 2018                64
# 748  0ZxZlO7oWCSYMXhehpyMvE       COIN  Summer 2018                64
# 749  0ZxZlO7oWCSYMXhehpyMvE       COIN  Summer 2018                64
#
#         artistGenre artistGenreUnique                 albumID  \
# 0                []                 0  0G9S31E4tXEPAdLTR6Os3M
# 1                []                 0  0G9S31E4tXEPAdLTR6Os3M
# 2                []                 0  0G9S31E4tXEPAdLTR6Os3M
# 3                []                 0  0G9S31E4tXEPAdLTR6Os3M
# 4                []                 0  0G9S31E4tXEPAdLTR6Os3M
# ..              ...               ...                     ...
# 745  ['pov: indie']        pov: indie  0Ysl8PFnCzqyvjbAhaCMvf
# 746  ['pov: indie']        pov: indie  0Ysl8PFnCzqyvjbAhaCMvf
# 747  ['pov: indie']        pov: indie  0Ysl8PFnCzqyvjbAhaCMvf
# 748  ['pov: indie']        pov: indie  0Ysl8PFnCzqyvjbAhaCMvf
# 749  ['pov: indie']        pov: indie  0Ysl8PFnCzqyvjbAhaCMvf
#
#                                  albumURI         albumName albumReleaseDate  \
# 0    spotify:album:0G9S31E4tXEPAdLTR6Os3M  This is the Show       2022-03-17
# 1    spotify:album:0G9S31E4tXEPAdLTR6Os3M  This is the Show       2022-03-17
# 2    spotify:album:0G9S31E4tXEPAdLTR6Os3M  This is the Show       2022-03-17
# 3    spotify:album:0G9S31E4tXEPAdLTR6Os3M  This is the Show       2022-03-17
# 4    spotify:album:0G9S31E4tXEPAdLTR6Os3M  This is the Show       2022-03-17
# ..                                    ...               ...              ...
# 745  spotify:album:0Ysl8PFnCzqyvjbAhaCMvf    Uncanny Valley       2022-03-25
# 746  spotify:album:0Ysl8PFnCzqyvjbAhaCMvf    Uncanny Valley       2022-03-25
# 747  spotify:album:0Ysl8PFnCzqyvjbAhaCMvf    Uncanny Valley       2022-03-25
# 748  spotify:album:0Ysl8PFnCzqyvjbAhaCMvf    Uncanny Valley       2022-03-25
# 749  spotify:album:0Ysl8PFnCzqyvjbAhaCMvf    Uncanny Valley       2022-03-25
#
#     albumType  albumPopularity                       genre  \
# 0       album             26.0  ModelList with items: [\n]
# 1       album             26.0  ModelList with items: [\n]
# 2       album             26.0  ModelList with items: [\n]
# 3       album             26.0  ModelList with items: [\n]
# 4       album             26.0  ModelList with items: [\n]
# ..        ...              ...                         ...
# 745     album             62.0  ModelList with items: [\n]
# 746     album             62.0  ModelList with items: [\n]
# 747     album             62.0  ModelList with items: [\n]
# 748     album             62.0  ModelList with items: [\n]
# 749     album             62.0  ModelList with items: [\n]
#
#                                   songURI
# 0    spotify:track:1CNZyTSa31wY4yEvURsG0u
# 1    spotify:track:5TentxEIR7mwmSA4okW7vS
# 2    spotify:track:6dfu0WnXMo7R2RPYOTx2oI
# 3    spotify:track:1OUCobP088zyQM4Tlkfq06
# 4    spotify:track:0fcc6Mx9PnZJzzVyiHU1ka
# ..                                    ...
# 745  spotify:track:37ultvoFXvydBENnPp4iyX
# 746  spotify:track:6YFbMdgXLOkwxLLJKOJmIn
# 747  spotify:track:4uPiqpmAwCM1ANkWHi9hw9
# 748  spotify:track:4xUvNjNyHbjlM0hWJgohsb
# 749  spotify:track:10K6D1EGwmBHzBv3cJHLQ5
#
# [750 rows x 14 columns]

# %%
# Select the next chunk
# Number of entries
lastNumber = 2000
newNumber = lastNumber+4000
songs = songs.iloc[lastNumber:newNumber]

# %%
# Sort by Popularity from center
# songs['sorter'] = songs['artistPopularity'] - 50
# songs['sorter'] = songs['sorter'].abs()
# songs = songs.sort_values('sorter', ignore_index=True)

# %% [markdown]
# ## Create an empty playlist in the user's account

# %%
# Create a playlist for the user
with spotify.token_as(user_token):
    newPlaylist = spotify.playlist_create(userID, "Summer Songs 2", public=False, description='Recent albums from Artist Candidates')
playlistID = newPlaylist.id

# %%
# Clear an existing playlist
with spotify.token_as(user_token):
    spotify.playlist_clear(playlistID)

# %% [markdown]
# ## Add the songs to the playlist

# %%
# Cut the df into chunks
n = 0
while n < len(songs):
    songsToAdd = songs.iloc[n:(n+100)]
    # Add songs to the playlist
    try:
        with spotify.token_as(user_token):
            additions = spotify.playlist_add(playlistID, list(songsToAdd['songURI']), position=None)
            # Wait 2 seconds so we do not exceed our API call allowance
            time.sleep(2)
    except: 
        with spotify.token_as(user_token):
            for songURI in songsToAdd['songURI']:
                try:
                    additions = spotify.playlist_add(playlistID, songURI, position=None)
                    # Wait 2 seconds so we do not exceed our API call allowance
                    time.sleep(2)
                except: 
                    pass
    n += 100

# %%
songs.loc[songs['artistName']=='Justine Skye']
# Out:
#                      artistID    artistName         artistSource  \
# 21677  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21678  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21679  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21680  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21681  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21682  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21683  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21684  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21685  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
# 21686  0jUQSUOcM7lxVn5eVGTkzQ  Justine Skye  big on the internet
#
#        artistPopularity         artistGenre artistGenreUnique  \
# 21677                71  ['pop r&b', 'r&b']           pop r&b
# 21678                71  ['pop r&b', 'r&b']           pop r&b
# 21679                71  ['pop r&b', 'r&b']           pop r&b
# 21680                71  ['pop r&b', 'r&b']           pop r&b
# 21681                71  ['pop r&b', 'r&b']           pop r&b
# 21682                71  ['pop r&b', 'r&b']           pop r&b
# 21683                71  ['pop r&b', 'r&b']           pop r&b
# 21684                71  ['pop r&b', 'r&b']           pop r&b
# 21685                71  ['pop r&b', 'r&b']           pop r&b
# 21686                71  ['pop r&b', 'r&b']           pop r&b
#
#                       albumID                              albumURI  \
# 21677  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21678  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21679  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21680  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21681  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21682  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21683  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21684  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21685  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# 21686  0FvZIwN0AHWYQVyuS3KR7H  spotify:album:0FvZIwN0AHWYQVyuS3KR7H
#
#        albumName albumReleaseDate albumType  albumPopularity  \
# 21677  Dark Side       2023-01-31     album             75.0
# 21678  Dark Side       2023-01-31     album             75.0
# 21679  Dark Side       2023-01-31     album             75.0
# 21680  Dark Side       2023-01-31     album             75.0
# 21681  Dark Side       2023-01-31     album             75.0
# 21682  Dark Side       2023-01-31     album             75.0
# 21683  Dark Side       2023-01-31     album             75.0
# 21684  Dark Side       2023-01-31     album             75.0
# 21685  Dark Side       2023-01-31     album             75.0
# 21686  Dark Side       2023-01-31     album             75.0
#
#                             genre                               songURI
# 21677  ModelList with items: [\n]  spotify:track:6FscsacxYI5HCHPOv2KtBG
# 21678  ModelList with items: [\n]  spotify:track:761I4NLAoiVbgcLL7uYxRp
# 21679  ModelList with items: [\n]  spotify:track:2PfrM8Gi5i8aNCc7xC5rw8
# 21680  ModelList with items: [\n]  spotify:track:1EzEMKwcft9DjD01EX9ye5
# 21681  ModelList with items: [\n]  spotify:track:4KsA6WNdIbBfmODXWh7eja
# 21682  ModelList with items: [\n]  spotify:track:4V1PjTKiIZoU2aLO4SAfUQ
# 21683  ModelList with items: [\n]  spotify:track:47zIZ8on4OGsLdO47wOVfw
# 21684  ModelList with items: [\n]  spotify:track:5r8ME4fjwxot90Ak4Uf1g5
# 21685  ModelList with items: [\n]  spotify:track:5kY2DRIom6dcVZbQb1SAX8
# 21686  ModelList with items: [\n]  spotify:track:2p6Fh5ruk8YUaO43huubHW

# %%
songs.iloc[6000]
# Out:
# artistID                           0jUQSUOcM7lxVn5eVGTkzQ
# artistName                                   Justine Skye
# artistSource                          big on the internet
# artistPopularity                                       71
# artistGenre                            ['pop r&b', 'r&b']
# artistGenreUnique                                 pop r&b
# albumID                            0FvZIwN0AHWYQVyuS3KR7H
# albumURI             spotify:album:0FvZIwN0AHWYQVyuS3KR7H
# albumName                                       Dark Side
# albumReleaseDate                      2023-01-31 00:00:00
# albumType                                           album
# albumPopularity                                      75.0
# genre                          ModelList with items: [\n]
# songURI              spotify:track:1EzEMKwcft9DjD01EX9ye5
# Name: 21680, dtype: object
