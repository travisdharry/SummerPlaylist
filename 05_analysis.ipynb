# %% [markdown]
# ## Configuration

# %%
### Configuration
# Import dependencies
import os
from collections import Counter
from datetime import datetime
from dateutil.relativedelta import relativedelta
import pandas as pd
from summerplaylist import *

# Environment variables
CLIENTID = os.environ.get('CLIENTID')
CLIENTSECRET = os.environ.get('CLIENTSECRET')
REDIRECT_URI = 'https://example.com/callback'

# %% [markdown]
# ## Log In

# %%
# Authenticate to Spotify
credentials = authenticateToSpotify(CLIENTID, CLIENTSECRET, REDIRECT_URI)
# Out:
# Opening browser for Spotify login...

# %% [markdown]
# ## Get info for each playlist

# %%
pl_top100 = getPlaylistID(credentials, "Summer 2024")
pl_top300 = getPlaylistID(credentials, "Endless Summer 2024")
pl_top500 = getPlaylistID(credentials, "Forever Summer 2024")

# %%
top100 = fetchTracksFromPlaylist(credentials, pl_top100)
top300 = fetchTracksFromPlaylist(credentials, pl_top300)
top500 = fetchTracksFromPlaylist(credentials, pl_top500)

# %%
top100['playlistName'] = "Summer 2024"
top300['playlistName'] = "Endless Summer 2024"
top500['playlistName'] = "Forever Summer 2024"

# %%
all = pd.concat([top100, top300, top500], axis=0, ignore_index=True)
all = all.drop_duplicates(subset=all.columns[:-1], ignore_index=True)

# %%
all
# Out:
#         artistName                artistID          songName release_date  \
# 0     Master Peace  4GNHtO2iEJ09r4JNTlqnO9   I Might be Fake   2024-03-01
# 1          Georgia  06knYh538h5SI7OAEF8ek3   I Might be Fake   2024-03-01
# 2             Nemo  5Wg72TowYBWIcSo3K2r84N          The Code   2024-02-29
# 3    alyona alyona  2ic3GGGmkixOZP4qnakSA8    Teresa & Maria   2024-01-11
# 4       Jerry Heil  71DkA619tW0bpaMi4QBzmr    Teresa & Maria   2024-01-11
# ..             ...                     ...               ...          ...
# 699        Oceanic  1HZqEalU7MGNHQvENPJb4J  Change Your Mind   2021-01-15
# 700     Eartheater  18ca9d5EU5R1AhVKPR1cm0          Crushing   2023-09-20
# 701         Nashon  12X1zDSQlW0c6uRXGoOzHi       love counts   2022-11-11
# 702          Geese  0WCo84qtCKfbyIf1lqQWB4        3D Country   2023-06-23
# 703       vaultboy  0K87f3owemzI8NUCoEIXOB  everything sucks   2021-05-21
#
#                                   songURI  songLocation  albumLength  \
# 0    spotify:track:5CnKkMbJpS2vNjLgH6k8w7             5           11
# 1    spotify:track:5CnKkMbJpS2vNjLgH6k8w7             5           11
# 2    spotify:track:1EjIXKhNHI00ZLMRpS8iz8             1            1
# 3    spotify:track:7n3Czk07KugPQOWuqCHDmF             1            1
# 4    spotify:track:7n3Czk07KugPQOWuqCHDmF             1            1
# ..                                    ...           ...          ...
# 699  spotify:track:0ryVvXd2EzVqNR0yTLCzNT             1            1
# 700  spotify:track:6BPwBHxjmavFAyMrLQgQYd             2            9
# 701  spotify:track:7hTIiQtyodbfSmrb1Th5Qr             1            1
# 702  spotify:track:6TLl4M9cQVHkPI75LTqABu             2           11
# 703  spotify:track:3z06k8YF9CqX0CGFrlekOK             1            1
#
#      songDuration  songExplicit  songPopularity         playlistName
# 0          168805         False              44          Summer 2024
# 1          168805         False              44          Summer 2024
# 2          180141         False              85          Summer 2024
# 3          179473         False              80          Summer 2024
# 4          179473         False              80          Summer 2024
# ..            ...           ...             ...                  ...
# 699        188866         False              32  Forever Summer 2024
# 700        271733         False              51  Forever Summer 2024
# 701        153750          True              28  Forever Summer 2024
# 702        313577          True              46  Forever Summer 2024
# 703        115401          True              68  Forever Summer 2024
#
# [704 rows x 11 columns]

# %%
artists = all
songs = all.drop_duplicates('songURI', ignore_index=True)

# %%
songs['songLocationRelative'] = songs['songLocation'] / songs['albumLength']
# Out:
# /var/folders/ss/nt9sccdn5w91sbtr85gybrnm0000gn/T/ipykernel_17509/1768759434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   songs['songLocationRelative'] = songs['songLocation'] / songs['albumLength']

# %%
songs
# Out:
#         artistName                artistID          songName release_date  \
# 0     Master Peace  4GNHtO2iEJ09r4JNTlqnO9   I Might be Fake   2024-03-01
# 1             Nemo  5Wg72TowYBWIcSo3K2r84N          The Code   2024-02-29
# 2    alyona alyona  2ic3GGGmkixOZP4qnakSA8    Teresa & Maria   2024-01-11
# 3            Dessa  2CQAfzpwwaMxj3YNlb4Gbj   Hurricane Party   2023-09-29
# 4      Sofi Tukker  586uxXMyD5ObPuzjtrzO1Q    Throw Some Ass   2024-05-03
# ..             ...                     ...               ...          ...
# 541        Oceanic  1HZqEalU7MGNHQvENPJb4J  Change Your Mind   2021-01-15
# 542     Eartheater  18ca9d5EU5R1AhVKPR1cm0          Crushing   2023-09-20
# 543         Nashon  12X1zDSQlW0c6uRXGoOzHi       love counts   2022-11-11
# 544          Geese  0WCo84qtCKfbyIf1lqQWB4        3D Country   2023-06-23
# 545       vaultboy  0K87f3owemzI8NUCoEIXOB  everything sucks   2021-05-21
#
#                                   songURI  songLocation  albumLength  \
# 0    spotify:track:5CnKkMbJpS2vNjLgH6k8w7             5           11
# 1    spotify:track:1EjIXKhNHI00ZLMRpS8iz8             1            1
# 2    spotify:track:7n3Czk07KugPQOWuqCHDmF             1            1
# 3    spotify:track:5rmg3dVtNulAP1DoqeUuYm             1           11
# 4    spotify:track:5YO44oPkpH4zeinnihUpIR             1            1
# ..                                    ...           ...          ...
# 541  spotify:track:0ryVvXd2EzVqNR0yTLCzNT             1            1
# 542  spotify:track:6BPwBHxjmavFAyMrLQgQYd             2            9
# 543  spotify:track:7hTIiQtyodbfSmrb1Th5Qr             1            1
# 544  spotify:track:6TLl4M9cQVHkPI75LTqABu             2           11
# 545  spotify:track:3z06k8YF9CqX0CGFrlekOK             1            1
#
#      songDuration  songExplicit  songPopularity         playlistName  \
# 0          168805         False              44          Summer 2024
# 1          180141         False              85          Summer 2024
# 2          179473         False              80          Summer 2024
# 3          153801          True              28          Summer 2024
# 4          182423         False              68          Summer 2024
# ..            ...           ...             ...                  ...
# 541        188866         False              32  Forever Summer 2024
# 542        271733         False              51  Forever Summer 2024
# 543        153750          True              28  Forever Summer 2024
# 544        313577          True              46  Forever Summer 2024
# 545        115401          True              68  Forever Summer 2024
#
#      songLocationRelative
# 0                0.454545
# 1                1.000000
# 2                1.000000
# 3                0.090909
# 4                1.000000
# ..                    ...
# 541              1.000000
# 542              0.222222
# 543              1.000000
# 544              0.181818
# 545              1.000000
#
# [546 rows x 12 columns]

# %%
songs['songLocationRelative'].median()
# Out:
# 0.4142156862745098

# %%
songs['songPopularity'].median()
# Out:
# 39.0

# %%
songs['songDuration'].median() / 60000
# Out:
# 3.1622
